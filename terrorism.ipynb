# %% [markdown]
# ## 모듈 임포트

# %%
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# 1. 필요없는 컬럼 삭제
# 2. 5년 단위로 나누기

# %%
df = pd.read_excel("gtdb70-20.xlsx")

# %%
df.drop(['eventid','imonth', 'iday','latitude', 'longitude', 'targsubtype1',
       'targsubtype1_txt', 'corp1', 'target1','natlty1', 'natlty1_txt','propextent', 'propextent_txt',
       'propvalue', 'dbsource','weapdetail', 'country', 'country_txt','weapsubtype1', 'weapsubtype1_txt'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
#        'targtype1', 'targtype1_txt', 'gname', 'weaptype1', 'weaptype1_txt'],
#       dtype='object')

# %%
df.sort_values('iyear', inplace=True)

# %%
df.drop(df.index[:71658], inplace =True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
for i in tqdm(range(len(df))):
    if df['targtype1_txt'][i] == 'Unknown':
        df['targtype1_txt'][i] = 'Unknown_target'
# Out:
#   0%|          | 0/138048 [00:00<?, ?it/s]
# C:\Users\user2303\AppData\Local\Temp\ipykernel_12356\2962488245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['targtype1_txt'][i] = 'Unknown_target'
# C:\Users\user2303\AppData\Local\Temp\ipykernel_12356\2962488245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['targtype1_txt'][i] = 'Unknown_target'
# C:\Users\user2303\AppData\Local\Temp\ipykernel_12356\2962488245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dfa = df[:7702]
dfb = df[7702:28060]
dfc = df[28060:85805]
dfd = df[85805:]

# %%
dfa.reset_index(drop=True, inplace=True)
dfb.reset_index(drop=True, inplace=True)
dfc.reset_index(drop=True, inplace=True)
dfd.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 통계분석 - 대륙별 통계분석

# %% [markdown]
# 1 = North America
# 2 = Central America & Caribbean
# 3 = South America
# 4 = East Asia
# 5 = Southeast Asia
# 6 = South Asia
# 7 = Central Asia
# 8 = Western Europe
# 9 = Eastern Europe
# 10 = Middle East & North Africa
# 11 = Sub-Saharan Africa
# 12 = Australasia & Oceania
#
# 1..3 -> america
# 4..7 -> asia
# 8..9 -> europe
# 10..11 -> africa
# 12 -> Australasia & Oceania

# %% [markdown]
# ### 대륙별 테러 수 통계

# %% [markdown]
# #### 2001~2005

# %%
america = 0
asia = 0
europe = 0
africa = 0
oceania = 0
for i in tqdm(range(len(dfa))):
    if dfa['region'][i]<=3:
            america += 1
    elif dfa['region'][i]<=7:
            asia += 1
    elif dfa['region'][i]<=9:
            europe += 1
    elif dfa['region'][i]<=11:
            africa += 1
    else:
            oceania += 1    
x = ['america', 'asia', 'europe', 'africa', 'oceania&australasia']
y = [america, asia, europe, africa, oceania]
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

plt.show()
# Out:
#   0%|          | 0/7702 [00:00<?, ?it/s]

# %% [markdown]
# #### 2006~2010

# %%
america = 0
asia = 0
europe = 0
africa = 0
oceania = 0
for i in tqdm(range(len(dfb))):
    if dfb['region'][i]<=3:
            america += 1
    elif dfb['region'][i]<=7:
            asia += 1
    elif dfb['region'][i]<=9:
            europe += 1
    elif dfb['region'][i]<=11:
            africa += 1
    else:
            oceania += 1    
x = ['america', 'asia', 'europe', 'africa', 'oceania&australasia']
y = [america, asia, europe, africa, oceania]
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

plt.show()
# Out:
#   0%|          | 0/20358 [00:00<?, ?it/s]

# %% [markdown]
# #### 2011~2015

# %%
america = 0
asia = 0
europe = 0
africa = 0
oceania = 0
for i in tqdm(range(len(dfc))):
    if dfc['region'][i]<=3:
            america += 1
    elif dfc['region'][i]<=7:
            asia += 1
    elif dfc['region'][i]<=9:
            europe += 1
    elif dfc['region'][i]<=11:
            africa += 1
    else:
            oceania += 1    
x = ['america', 'asia', 'europe', 'africa', 'oceania&australasia']
y = [america, asia, europe, africa, oceania]
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

plt.show()
# Out:
#   0%|          | 0/57745 [00:00<?, ?it/s]

# %% [markdown]
# #### 2016~2020

# %%
america = 0
asia = 0
europe = 0
africa = 0
oceania = 0
for i in tqdm(range(len(dfd))):
    if dfd['region'][i]<=3:
            america += 1
    elif dfd['region'][i]<=7:
            asia += 1
    elif dfd['region'][i]<=9:
            europe += 1
    elif dfd['region'][i]<=11:
            africa += 1
    else:
            oceania += 1    
x = ['america', 'asia', 'europe', 'africa', 'oceania&australasia']
y = [america, asia, europe, africa, oceania]
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

plt.show()
# Out:
#   0%|          | 0/52243 [00:00<?, ?it/s]

# %% [markdown]
# ### 테러 수단 비율 통계

# %% [markdown]
# #### 2001~2005

# %%
a = dfa['weaptype1_txt'].value_counts().to_frame()
a.reset_index(drop=False,inplace=True)
a.rename(columns={'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)':'Vehicle'}, inplace=True)
x = ['Explosives', 'Firearms', 'Incendiary', 'Unknown', 'Melee',
       'Chemical', 'Biological',
       'Vehicle',
       'Sabotage Equipment', 'Other', 'Fake Weapons']
y = []
for i in range(len(a)):
    y.append(a['count'][i])
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')
    plt.xticks(rotation=45, fontsize=6)# verticalalignment (top, center, bottom)

plt.show()

# %% [markdown]
# #### 2006~2010

# %%
b = dfb['weaptype1_txt'].value_counts().to_frame()
b.reset_index(drop=False,inplace=True)
b.rename(columns={'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)':'Vehicle'}, inplace=True)
x = ['Explosives', 'Firearms', 'Incendiary', 'Unknown', 'Melee',
       'Chemical', 'Biological',
       'Vehicle',
       'Sabotage Equipment', 'Other', 'Fake Weapons']
y = []
for i in range(len(b)):
    y.append(b['count'][i])
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')
    plt.xticks(rotation=45, fontsize=6)# verticalalignment (top, center, bottom)

plt.show()

# %% [markdown]
# #### 2011~2015

# %%
c = dfc['weaptype1_txt'].value_counts().to_frame()
c.reset_index(drop=False,inplace=True)
c.rename(columns={'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)':'Vehicle'}, inplace=True)
x = ['Explosives', 'Firearms', 'Incendiary', 'Unknown', 'Melee',
       'Chemical', 'Biological',
       'Vehicle',
       'Sabotage Equipment', 'Other', 'Fake Weapons']
y = []
for i in range(len(c)):
    y.append(c['count'][i])
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')
    plt.xticks(rotation=45, fontsize=6)# verticalalignment (top, center, bottom)

plt.show()

# %% [markdown]
# #### 2016~2020

# %%
d = dfd['weaptype1_txt'].value_counts().to_frame()
d.reset_index(drop=False,inplace=True)
d.rename(columns={'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)':'Vehicle'}, inplace=True)
x = ['Explosives', 'Firearms', 'Incendiary', 'Unknown', 'Melee',
       'Chemical', 'Biological',
       'Vehicle',
       'Sabotage Equipment', 'Other', 'Fake Weapons']
y = []
for i in range(len(d)):
    y.append(d['count'][i])
plt.bar(x,y)
for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')
    plt.xticks(rotation=45, fontsize=6)# verticalalignment (top, center, bottom)

plt.show()

# %% [markdown]
# ## 데이터베이스 구축

# %% [markdown]
# ### 대륙별 테러집단

# %% [markdown]
# #### 2001~2005

# %% [markdown]
# ##### asia

# %% [markdown]
# 아시아만 골라내기

# %%
dfaasia = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfa))):
    if 4<=dfa['region'][i]<=7:
        dfaasia.loc[len(dfaasia)] = dfa.iloc[i]

dfaasia.drop(['region','region_txt'],axis=1,inplace=True)

dfaasia.insert(1,'region','asia')
dfaasia.to_excel('C:/Users/user2303/terrorism/result/1/a_asia.xlsx', index=False)
# Out:
#   0%|          | 0/7702 [00:00<?, ?it/s]

# %% [markdown]
# 아시아 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfaasia['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfaasiafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Taliban', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', 
     'Moro Islamic Liberation Front (MILF)']
for i in tqdm(range(len(dfaasia))):
    if dfaasia['gname'][i] in l:
        dfaasiafinal.loc[len(dfaasiafinal)] = dfaasia.iloc[i]

dfaasiafinal.to_excel('C:/Users/user2303/terrorism/result/1/a_asia.xlsx', index=False)'''
# Out:
# "dfaasiafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Taliban', 'Maoists', 'Liberation Tigers of Tamil Eelam (LTTE)', \n     'Moro Islamic Liberation Front (MILF)']\nfor i in tqdm(range(len(dfaasia))):\n    if dfaasia['gname'][i] in l:\n        dfaasiafinal.loc[len(dfaasiafinal)] = dfaasia.iloc[i]\n\ndfaasiafinal.to_excel('C:/Users/user2303/terrorism/result/1/a_asia.xlsx', index=False)"

# %% [markdown]
# ##### africa

# %% [markdown]
# 아프리카만 골라내기

# %%
dfaafrica = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfa))):
    if 10<=dfa['region'][i]<=11:
        dfaafrica.loc[len(dfaafrica)] = dfa.iloc[i]

dfaafrica.drop(['region','region_txt'],axis=1,inplace=True)

dfaafrica.insert(1,'region','africa')
dfaafrica.to_excel('C:/Users/user2303/terrorism/result/1/a_africa.xlsx', index=False)
# Out:
#   0%|          | 0/7702 [00:00<?, ?it/s]

# %% [markdown]
# 아프리카 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfaafrica['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfaafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Algerian Islamic Extremists', 'Salafist Group for Preaching and Fighting (GSPC)', 'Hamas (Islamic Resistance Movement)', 
     'Al-Aqsa Martyrs Brigade']
for i in tqdm(range(len(dfaafrica))):
    if dfaafrica['gname'][i] in l:
        dfaafricafinal.loc[len(dfaafricafinal)] = dfaafrica.iloc[i]

dfaafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/a_africa.xlsx', index=False)'''
# Out:
# "dfaafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Algerian Islamic Extremists', 'Salafist Group for Preaching and Fighting (GSPC)', 'Hamas (Islamic Resistance Movement)', \n     'Al-Aqsa Martyrs Brigade']\nfor i in tqdm(range(len(dfaafrica))):\n    if dfaafrica['gname'][i] in l:\n        dfaafricafinal.loc[len(dfaafricafinal)] = dfaafrica.iloc[i]\n\ndfaafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/a_africa.xlsx', index=False)"

# %% [markdown]
# ##### europe

# %% [markdown]
# 유럽만 골라내기

# %%
dfaeurope = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfa))):
    if 8<=dfa['region'][i]<=9:
        dfaeurope.loc[len(dfaeurope)] = dfa.iloc[i]

dfaeurope.drop(['region','region_txt'],axis=1,inplace=True)

dfaeurope.insert(1,'region','europe')
dfaeurope.to_excel('C:/Users/user2303/terrorism/result/1/a_europe.xlsx', index=False)
# Out:
#   0%|          | 0/7702 [00:00<?, ?it/s]

# %% [markdown]
# 유럽 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfaeurope['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfaeuropefinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Algerian Islamic Extremists', 'Salafist Group for Preaching and Fighting (GSPC)', 'Hamas (Islamic Resistance Movement)', 
     'Al-Aqsa Martyrs Brigade']
for i in tqdm(range(len(dfaeurope))):
    if dfaeurope['gname'][i] in l:
        dfaeuropefinal.loc[len(dfaeuropefinal)] = dfaeurope.iloc[i]

dfaeuropefinal.to_excel('C:/Users/user2303/terrorism/result/1/a_europe.xlsx', index=False)'''
# Out:
# "dfaeuropefinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Algerian Islamic Extremists', 'Salafist Group for Preaching and Fighting (GSPC)', 'Hamas (Islamic Resistance Movement)', \n     'Al-Aqsa Martyrs Brigade']\nfor i in tqdm(range(len(dfaeurope))):\n    if dfaeurope['gname'][i] in l:\n        dfaeuropefinal.loc[len(dfaeuropefinal)] = dfaeurope.iloc[i]\n\ndfaeuropefinal.to_excel('C:/Users/user2303/terrorism/result/1/a_europe.xlsx', index=False)"

# %% [markdown]
# #### 2006~2010

# %% [markdown]
# ##### asia

# %% [markdown]
# 아시아만 골라내기

# %%
dfbasia = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfb))):
    if 4<=dfb['region'][i]<=7:
        dfbasia.loc[len(dfbasia)] = dfb.iloc[i]

dfbasia.drop(['region','region_txt'],axis=1,inplace=True)

dfbasia.insert(1,'region','asia')
dfbasia.to_excel('C:/Users/user2303/terrorism/result/1/b_asia.xlsx', index=False)
# Out:
#   0%|          | 0/20358 [00:00<?, ?it/s]

# %% [markdown]
# 아시아 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfbasia['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfbasiafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Liberation Tigers of Tamil Eelam (LTTE)', 
     'Tehrik-i-Taliban Pakistan (TTP)']
for i in tqdm(range(len(dfbasia))):
    if dfbasia['gname'][i] in l:
        dfbasiafinal.loc[len(dfbasiafinal)] = dfbasia.iloc[i]

dfbasiafinal.to_excel('C:/Users/user2303/terrorism/result/1/b_asia.xlsx', index=False)'''
# Out:
# "dfbasiafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Liberation Tigers of Tamil Eelam (LTTE)', \n     'Tehrik-i-Taliban Pakistan (TTP)']\nfor i in tqdm(range(len(dfbasia))):\n    if dfbasia['gname'][i] in l:\n        dfbasiafinal.loc[len(dfbasiafinal)] = dfbasia.iloc[i]\n\ndfbasiafinal.to_excel('C:/Users/user2303/terrorism/result/1/b_asia.xlsx', index=False)"

# %% [markdown]
# ##### africa

# %% [markdown]
# 아프리카만 골라내기

# %%
dfbafrica = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfb))):
    if 10<=dfb['region'][i]<=11:
        dfbafrica.loc[len(dfbafrica)] = dfb.iloc[i]

dfbafrica.drop(['region','region_txt'],axis=1,inplace=True)

dfbafrica.insert(1,'region','africa')
dfbafrica.to_excel('C:/Users/user2303/terrorism/result/1/b_africa.xlsx', index=False)
# Out:
#   0%|          | 0/20358 [00:00<?, ?it/s]

# %% [markdown]
# 아프리카 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfbafrica['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfbafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tehrik-i-Taliban Pakistan (TTP)', 
     'Liberation Tigers of Tamil Eelam (LTTE)']
for i in tqdm(range(len(dfbafrica))):
    if dfbafrica['gname'][i] in l:
        dfbafricafinal.loc[len(dfbafricafinal)] = dfbafrica.iloc[i]

dfbafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/b_africa.xlsx', index=False)'''
# Out:
# "dfbafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Taliban', 'Communist Party of India - Maoist (CPI-Maoist)', 'Tehrik-i-Taliban Pakistan (TTP)', \n     'Liberation Tigers of Tamil Eelam (LTTE)']\nfor i in tqdm(range(len(dfbafrica))):\n    if dfbafrica['gname'][i] in l:\n        dfbafricafinal.loc[len(dfbafricafinal)] = dfbafrica.iloc[i]\n\ndfbafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/b_africa.xlsx', index=False)"

# %% [markdown]
# ##### europe

# %% [markdown]
# 유럽만 골라내기

# %%
dfbeurope = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfb))):
    if 8<=dfb['region'][i]<=9:
        dfbeurope.loc[len(dfbeurope)] = dfb.iloc[i]

dfbeurope.drop(['region','region_txt'],axis=1,inplace=True)

dfbeurope.insert(1,'region','europe')
dfbeurope.to_excel('C:/Users/user2303/terrorism/result/1/b_europe.xlsx', index=False)
# Out:
#   0%|          | 0/20358 [00:00<?, ?it/s]

# %% [markdown]
# 유럽 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfbeurope['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfbeuropefinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Algerian Islamic Extremists', 'Al-Shabaab', 'Al-Qaida in the Islamic Maghreb (AQIM)', 
     'Al-Qaida in Iraq']
for i in tqdm(range(len(dfbeurope))):
    if dfbeurope['gname'][i] in l:
        dfbeuropefinal.loc[len(dfbeuropefinal)] = dfbeurope.iloc[i]

dfbeuropefinal.to_excel('C:/Users/user2303/terrorism/result/1/b_europe.xlsx', index=False)'''
# Out:
# "dfbeuropefinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Algerian Islamic Extremists', 'Al-Shabaab', 'Al-Qaida in the Islamic Maghreb (AQIM)', \n     'Al-Qaida in Iraq']\nfor i in tqdm(range(len(dfbeurope))):\n    if dfbeurope['gname'][i] in l:\n        dfbeuropefinal.loc[len(dfbeuropefinal)] = dfbeurope.iloc[i]\n\ndfbeuropefinal.to_excel('C:/Users/user2303/terrorism/result/1/b_europe.xlsx', index=False)"

# %% [markdown]
# #### 2011~2015

# %% [markdown]
# ##### asia

# %% [markdown]
# 아시아만 골라내기

# %%
dfcasia = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfc))):
    if 4<=dfc['region'][i]<=7:
        dfcasia.loc[len(dfcasia)] = dfc.iloc[i]

dfcasia.drop(['region','region_txt'],axis=1,inplace=True)

dfcasia.insert(1,'region','asia')
dfcasia.to_excel('C:/Users/user2303/terrorism/result/1/c_asia.xlsx', index=False)
# Out:
#   0%|          | 0/57745 [00:00<?, ?it/s]

# %% [markdown]
# 아시아 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfcasia['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfcasiafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Taliban', "New People's Army (NPA)", 'Maoists', 
     'Tehrik-i-Taliban Pakistan (TTP)']
for i in tqdm(range(len(dfcasia))):
    if dfcasia['gname'][i] in l:
        dfcasiafinal.loc[len(dfcasiafinal)] = dfcasia.iloc[i]

dfcasiafinal.to_excel('C:/Users/user2303/terrorism/result/1/c_asia.xlsx', index=False)'''
# Out:
# 'dfcasiafinal = pd.DataFrame(columns=[\'iyear\', \'region\', \'attacktype1\', \'attacktype1_txt\',\n       \'gname\', \'weaptype1\', \'weaptype1_txt\', \'targtype1\', \'targtype1_txt\'])\n\nl = [\'Unknown\', \'Taliban\', "New People\'s Army (NPA)", \'Maoists\', \n     \'Tehrik-i-Taliban Pakistan (TTP)\']\nfor i in tqdm(range(len(dfcasia))):\n    if dfcasia[\'gname\'][i] in l:\n        dfcasiafinal.loc[len(dfcasiafinal)] = dfcasia.iloc[i]\n\ndfcasiafinal.to_excel(\'C:/Users/user2303/terrorism/result/1/c_asia.xlsx\', index=False)'

# %% [markdown]
# ##### africa

# %% [markdown]
# 아프리카만 골라내기

# %%
dfcafrica = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfc))):
    if 10<=dfc['region'][i]<=11:
        dfcafrica.loc[len(dfcafrica)] = dfc.iloc[i]

dfcafrica.drop(['region','region_txt'],axis=1,inplace=True)

dfcafrica.insert(1,'region','africa')
dfcafrica.to_excel('C:/Users/user2303/terrorism/result/1/c_africa.xlsx', index=False)
# Out:
#   0%|          | 0/57745 [00:00<?, ?it/s]

# %% [markdown]
# 아프리카 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfcafrica['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfcafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Shabaab', 'Boko Haram', 
     'Al-Qaida in the Arabian Peninsula (AQAP)']
for i in tqdm(range(len(dfcafrica))):
    if dfcafrica['gname'][i] in l:
        dfcafricafinal.loc[len(dfcafricafinal)] = dfcafrica.iloc[i]

dfcafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/c_africa.xlsx', index=False)'''
# Out:
# "dfcafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',\n       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])\n\nl = ['Unknown', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Shabaab', 'Boko Haram', \n     'Al-Qaida in the Arabian Peninsula (AQAP)']\nfor i in tqdm(range(len(dfcafrica))):\n    if dfcafrica['gname'][i] in l:\n        dfcafricafinal.loc[len(dfcafricafinal)] = dfcafrica.iloc[i]\n\ndfcafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/c_africa.xlsx', index=False)"

# %% [markdown]
# ##### europe

# %% [markdown]
# 유럽만 골라내기

# %%
dfceurope = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfc))):
    if 8<=dfc['region'][i]<=9:
        dfceurope.loc[len(dfceurope)] = dfc.iloc[i]

dfceurope.drop(['region','region_txt'],axis=1,inplace=True)

dfceurope.insert(1,'region','europe')
dfceurope.to_excel('C:/Users/user2303/terrorism/result/1/c_europe.xlsx', index=False)
# Out:
#   0%|          | 0/57745 [00:00<?, ?it/s]

# %% [markdown]
# 유럽 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfceurope['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfceuropefinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Shabaab', 'Boko Haram ', 
     'Al-Qaida in the Arabian Peninsula (AQAP)']
for i in tqdm(range(len(dfceurope))):
    if dfceurope['gname'][i] in l:
        dfceuropefinal.loc[len(dfceuropefinal)] = dfceurope.iloc[i]

dfceuropefinal.to_excel('C:/Users/user2303/terrorism/result/1/c_europe.xlsx', index=False)'''

# %% [markdown]
# #### 2016~2020

# %% [markdown]
# ##### asia

# %% [markdown]
# 아시아만 골라내기

# %%
dfdasia = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfd))):
    if 4<=dfd['region'][i]<=7:
        dfdasia.loc[len(dfdasia)] = dfd.iloc[i]

dfdasia.drop(['region','region_txt'],axis=1,inplace=True)

dfdasia.insert(1,'region','asia')
dfdasia.to_excel('C:/Users/user2303/terrorism/result/1/d_asia.xlsx', index=False)

# %% [markdown]
# 아시아 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfdasia['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfdasiafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Taliban', "New People's Army (NPA)", 'Maoists', 
     'Khorasan Chapter of the Islamic State']
for i in tqdm(range(len(dfdasia))):
    if dfdasia['gname'][i] in l:
        dfdasiafinal.loc[len(dfdasiafinal)] = dfdasia.iloc[i]

#dfdasiafinal.to_excel('C:/Users/user2303/terrorism/result/1/d_asia.xlsx', index=False)'''

# %% [markdown]
# ##### africa

# %% [markdown]
# 아프리카만 골라내기

# %%
dfdafrica = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfd))):
    if 10<=dfd['region'][i]<=11:
        dfdafrica.loc[len(dfdafrica)] = dfd.iloc[i]

dfdafrica.drop(['region','region_txt'],axis=1,inplace=True)

dfdafrica.insert(1,'region','africa')
dfdafrica.to_excel('C:/Users/user2303/terrorism/result/1/d_africa.xlsx', index=False)

# %% [markdown]
# 아프리카 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfdafrica['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfdafricafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'Islamic State of Iraq and the Levant (ISIL)', 'Al-Shabaab', 'Boko Haram', 
     'Houthi extremists (Ansar Allah)']
for i in tqdm(range(len(dfdafrica))):
    if dfdafrica['gname'][i] in l:
        dfdafricafinal.loc[len(dfdafricafinal)] = dfdafrica.iloc[i]

#dfdafricafinal.to_excel('C:/Users/user2303/terrorism/result/1/d_africa.xlsx', index=False)'''

# %% [markdown]
# ##### america

# %% [markdown]
# 아메리카만 골라내기

# %%
dfdamerica = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfd))):
    if 1<=dfd['region'][i]<=3:
        dfdamerica.loc[len(dfdamerica)] = dfd.iloc[i]

dfdamerica.drop(['region','region_txt'],axis=1,inplace=True)

dfdamerica.insert(1,'region','america')
dfdamerica.to_excel('C:/Users/user2303/terrorism/result/1/d_america.xlsx', index=False)

# %% [markdown]
# 아메리카 내에서 높은 테러 비율 보이는 집단 5개 추출

# %%
#dfdamerica['gname'].value_counts().head(5)

# %% [markdown]
# 최종 데이터베이스 완성 및 추출

# %%
'''dfdamericafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

l = ['Unknown', 'National Liberation Army of Colombia (ELN)', 'Revolutionary Armed Forces of Colombia (FARC) dissidents', 'Mapuche extremists', 
     'White supremacists/nationalists']
for i in tqdm(range(len(dfdamerica))):
    if dfdamerica['gname'][i] in l:
        dfdamericafinal.loc[len(dfdamericafinal)] = dfdamerica.iloc[i]

#dfdamericafinal.to_excel('C:/Users/user2303/terrorism/result/1/d_america.xlsx', index=False)'''

# %% [markdown]
# ### 대륙별 테러수단(explosive)

# %% [markdown]
# #### 2001~2005

# %% [markdown]
# ##### asia

# %%
dfaasiafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfaasia))):
    if dfaasia['weaptype1_txt'][i] == "Explosives":
        dfaasiafinal2.loc[len(dfaasiafinal2)] = dfaasia.iloc[i]
dfaasiafinal2.to_excel("C:/Users/user2303/terrorism/result/2/a_asia.xlsx", index=False)
# Out:
#   0%|          | 0/2869 [00:00<?, ?it/s]

# %% [markdown]
# ##### africa

# %%
dfaafricafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfaafrica))):
    if dfaafrica['weaptype1_txt'][i] == "Explosives":
        dfaafricafinal2.loc[len(dfaafricafinal2)] = dfaafrica.iloc[i]
dfaafricafinal2.to_excel("C:/Users/user2303/terrorism/result/2/a_africa.xlsx", index=False)
# Out:
#   0%|          | 0/2819 [00:00<?, ?it/s]

# %% [markdown]
# ##### europe

# %%
dfaeuropefinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfaeurope))):
    if dfaeurope['weaptype1_txt'][i] == "Explosives":
        dfaeuropefinal2.loc[len(dfaeuropefinal2)] = dfaeurope.iloc[i]
dfaeuropefinal2.to_excel("C:/Users/user2303/terrorism/result/2/a_europe.xlsx", index=False)
# Out:
#   0%|          | 0/1221 [00:00<?, ?it/s]

# %% [markdown]
# #### 2006~2010

# %% [markdown]
# ##### asia

# %%
dfbasiafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfbasia))):
    if dfbasia['weaptype1_txt'][i] == "Explosives":
        dfbasiafinal2.loc[len(dfbasiafinal2)] = dfbasia.iloc[i]
dfbasiafinal2.to_excel("C:/Users/user2303/terrorism/result/2/b_asia.xlsx", index=False)
# Out:
#   0%|          | 0/9913 [00:00<?, ?it/s]

# %% [markdown]
# ##### africa

# %%
dfbafricafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfbafrica))):
    if dfbafrica['weaptype1_txt'][i] == "Explosives":
        dfbafricafinal2.loc[len(dfbafricafinal2)] = dfbafrica.iloc[i]
dfbafricafinal2.to_excel("C:/Users/user2303/terrorism/result/2/b_africa.xlsx", index=False)
# Out:
#   0%|          | 0/8339 [00:00<?, ?it/s]

# %% [markdown]
# ##### europe

# %%
dfbeuropefinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfbeurope))):
    if dfbeurope['weaptype1_txt'][i] == "Explosives":
        dfbeuropefinal2.loc[len(dfbeuropefinal2)] = dfbeurope.iloc[i]
dfbeuropefinal2.to_excel("C:/Users/user2303/terrorism/result/2/b_europe.xlsx", index=False)
# Out:
#   0%|          | 0/1418 [00:00<?, ?it/s]

# %% [markdown]
# #### 2011~2015

# %% [markdown]
# ##### asia

# %%
dfcasiafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfcasia))):
    if dfcasia['weaptype1_txt'][i] == "Explosives":
        dfcasiafinal2.loc[len(dfcasiafinal2)] = dfcasia.iloc[i]
dfcasiafinal2.to_excel("C:/Users/user2303/terrorism/result/2/c_asia.xlsx", index=False)
# Out:
#   0%|          | 0/24567 [00:00<?, ?it/s]

# %% [markdown]
# ##### africa

# %%
dfcafricafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfcafrica))):
    if dfcafrica['weaptype1_txt'][i] == "Explosives":
        dfcafricafinal2.loc[len(dfcafricafinal2)] = dfcafrica.iloc[i]
dfcafricafinal2.to_excel("C:/Users/user2303/terrorism/result/2/c_africa.xlsx", index=False)
# Out:
#   0%|          | 0/28783 [00:00<?, ?it/s]

# %% [markdown]
# ##### europe

# %%
dfceuropefinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfceurope))):
    if dfceurope['weaptype1_txt'][i] == "Explosives":
        dfceuropefinal2.loc[len(dfceuropefinal2)] = dfceurope.iloc[i]
dfceuropefinal2.to_excel("C:/Users/user2303/terrorism/result/2/c_europe.xlsx", index=False)
# Out:
#   0%|          | 0/3282 [00:00<?, ?it/s]

# %% [markdown]
# #### 2016~2020

# %% [markdown]
# ##### asia

# %%
dfdasiafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfdasia))):
    if dfdasia['weaptype1_txt'][i] == "Explosives":
        dfdasiafinal2.loc[len(dfdasiafinal2)] = dfdasia.iloc[i]
dfdasiafinal2.to_excel("C:/Users/user2303/terrorism/result/2/d_asia.xlsx", index=False)
# Out:
#   0%|          | 0/21028 [00:00<?, ?it/s]

# %% [markdown]
# ##### africa

# %%
dfdafricafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfdafrica))):
    if dfdafrica['weaptype1_txt'][i] == "Explosives":
        dfdafricafinal2.loc[len(dfdafricafinal2)] = dfdafrica.iloc[i]
dfdafricafinal2.to_excel("C:/Users/user2303/terrorism/result/2/d_africa.xlsx", index=False)
# Out:
#   0%|          | 0/27692 [00:00<?, ?it/s]

# %% [markdown]
# ##### america

# %%
dfdamericafinal2 = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(dfdamerica))):
    if dfdamerica['weaptype1_txt'][i] == "Explosives":
        dfdamericafinal2.loc[len(dfdamericafinal2)] = dfdamerica.iloc[i]
dfdamericafinal2.to_excel("C:/Users/user2303/terrorism/result/2/d_america.xlsx", index=False)
# Out:
#   0%|          | 0/1776 [00:00<?, ?it/s]

# %% [markdown]
# ### 전체 데이터베이스에서 테러수단 상위 3개 - 집단

# %% [markdown]
# ##### 2001~2005

# %%
dfaconcat = pd.concat([dfaasia,dfaafrica,dfaeurope], ignore_index=True)
dfafinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfaconcat))):
    if dfaconcat['weaptype1_txt'][i] == 'Explosives':
        dfafinal.loc[len(dfafinal)] = dfaconcat.iloc[i]
    elif dfaconcat['weaptype1_txt'][i] == 'Firearms':
        dfafinal.loc[len(dfafinal)] = dfaconcat.iloc[i] 
    elif dfaconcat['weaptype1_txt'][i] == 'Incendiary':
        dfafinal.loc[len(dfafinal)] = dfaconcat.iloc[i]
dfafinal.to_excel('C:/Users/user2303/terrorism/result/3/a_final.xlsx',index=False)
# Out:
#   0%|          | 0/6909 [00:00<?, ?it/s]

# %% [markdown]
# ##### 2006~2010

# %%
dfbconcat = pd.concat([dfbasia,dfbafrica,dfbeurope], ignore_index=True)
dfbfinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfbconcat))):
    if dfbconcat['weaptype1_txt'][i] == 'Explosives':
        dfbfinal.loc[len(dfbfinal)] = dfbconcat.iloc[i]
    elif dfbconcat['weaptype1_txt'][i] == 'Firearms':
        dfbfinal.loc[len(dfbfinal)] = dfbconcat.iloc[i] 
    elif dfbconcat['weaptype1_txt'][i] == 'Incendiary':
        dfbfinal.loc[len(dfbfinal)] = dfbconcat.iloc[i]
dfbfinal.to_excel('C:/Users/user2303/terrorism/result/3/b_final.xlsx',index=False)
# Out:
#   0%|          | 0/19670 [00:00<?, ?it/s]

# %% [markdown]
# ##### 2011~2015

# %%
dfcconcat = pd.concat([dfcasia,dfcafrica,dfceurope], ignore_index=True)
dfcfinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfcconcat))):
    if dfcconcat['weaptype1_txt'][i] == 'Explosives':
        dfcfinal.loc[len(dfcfinal)] = dfcconcat.iloc[i]
    elif dfcconcat['weaptype1_txt'][i] == 'Firearms':
        dfcfinal.loc[len(dfcfinal)] = dfcconcat.iloc[i] 
    elif dfcconcat['weaptype1_txt'][i] == 'Incendiary':
        dfcfinal.loc[len(dfcfinal)] = dfcconcat.iloc[i]
dfcfinal.to_excel('C:/Users/user2303/terrorism/result/3/c_final.xlsx',index=False)
# Out:
#   0%|          | 0/56632 [00:00<?, ?it/s]

# %% [markdown]
# ##### 2016~2020

# %%
dfdconcat = pd.concat([dfdasia,dfdafrica,dfdamerica], ignore_index=True)
dfdfinal = pd.DataFrame(columns=['iyear', 'region', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])

for i in tqdm(range(len(dfdconcat))):
    if dfdconcat['weaptype1_txt'][i] == 'Explosives':
        dfdfinal.loc[len(dfdfinal)] = dfdconcat.iloc[i]
    elif dfdconcat['weaptype1_txt'][i] == 'Firearms':
        dfdfinal.loc[len(dfdfinal)] = dfdconcat.iloc[i] 
    elif dfdconcat['weaptype1_txt'][i] == 'Incendiary':
        dfdfinal.loc[len(dfafinal)] = dfdconcat.iloc[i]
dfdfinal.to_excel('C:/Users/user2303/terrorism/result/3/d_final.xlsx',index=False)
# Out:
#   0%|          | 0/50496 [00:00<?, ?it/s]

# %% [markdown]
# ### 대륙별 집단 추출(시대 안가리고)

# %% [markdown]
# #### 아시아

# %%
dfasia = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(df))):
    if 4<=df['region'][i]<=7:
        dfasia.loc[len(dfasia)] = df.iloc[i]
        
dfasia.drop(['region','region_txt'],axis=1,inplace=True)
dfasia.insert(1,'region','asia')
dfasia.to_excel('C:/Users/user2303/terrorism/result/4(시대안가리고대륙별)/asia.xlsx', index=False)
# Out:
#   0%|          | 0/138048 [00:00<?, ?it/s]

# %% [markdown]
# #### 아프리카

# %%
dfafrica = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(df))):
    if 10<=df['region'][i]<=11:
        dfafrica.loc[len(dfafrica)] = df.iloc[i]
dfafrica.drop(['region','region_txt'],axis=1,inplace=True)
dfafrica.insert(1,'region','africa')
dfafrica.to_excel('C:/Users/user2303/terrorism/result/4(시대안가리고대륙별)/africa.xlsx', index=False)
# Out:
#   0%|          | 0/138048 [00:00<?, ?it/s]

# %% [markdown]
# #### 유럽

# %%
dfeurope = pd.DataFrame(columns=['iyear', 'region', 'region_txt', 'attacktype1', 'attacktype1_txt',
       'gname', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt'])
for i in tqdm(range(len(df))):
    if 8<=df['region'][i]<=9:
        dfeurope.loc[len(dfeurope)] = df.iloc[i]
dfeurope.drop(['region','region_txt'],axis=1,inplace=True)
dfeurope.insert(1,'region','europe')
dfeurope.to_excel('C:/Users/user2303/terrorism/result/4(시대안가리고대륙별)/europe.xlsx', index=False)
# Out:
#   0%|          | 0/138048 [00:00<?, ?it/s]
